# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
ds_sort = ds.sort_values(by= 'price', ascending= False)


ds_sort.head(1)

ExpensiveHouse_Price = ds_sort.iloc[0]['price']
print(ExpensiveHouse_Price)

ExpensiveHouse_Address = ds_sort.iloc[0]['address']
ExpensiveHouse_Address

print(f"The house with address {ExpensiveHouse_Address} is the most expensive and its price is {ExpensiveHouse_Price} USD")
# Out:
# 8500000
# The house with address El Escorial is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
ds[ds['price'] > 0].iloc[0]['price']
# Out:
# 195000

# %%
ds_sort = ds.sort_values(by= 'price', ascending= True)

ds_sort.head(1)

CheapestHouse_Price = ds_sort[ds_sort['price'] > 0].iloc[0]['price']
print(CheapestHouse_Price)

CheapestHouse_Address = ds_sort[ds_sort['price'] > 0].iloc[0]['address']
CheapestHouse_Address

print(f"The house with address {CheapestHouse_Address} is the cheapest and its price is {CheapestHouse_Price} USD")
# Out:
# 600
# The house with address Berlin, Coslada is the cheapest and its price is 600 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
ds_sort_big = ds.sort_values(by= 'surface', ascending= False)

ds_sort_small = ds.sort_values(by= 'surface', ascending= True)

BiggestHouse_Address = ds_sort_big.iloc[0]['address']

SmallestHouse_Address = ds_sort_small.iloc[0]['address']

BiggestHouse_Surface = ds_sort_big.iloc[0]['surface']
SmallestHouse_Surface = ds_sort_small.iloc[0]['surface']

print(f'The bigger house is located on {BiggestHouse_Address} and its surface is {BiggestHouse_Surface} meters')
print(f'The smaller house is located on {SmallestHouse_Address} and its surface is {SmallestHouse_Surface} meters')
# Out:
# The bigger house is located on Sevilla la Nueva and its surface is 249000.0 meters
# The smaller house is located on Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
populations_list = ds['level5'].to_list()

populations_set = set(populations_list)

populations_list = list(populations_set)

print(populations_list)
# Out:
# ['Torrejón de la Calzada', 'Valverde de Alcalá', 'Valdetorres de Jarama', 'Villalbilla', 'El Berrueco', 'San Martín de la Vega', 'Fresno de Torote', 'Colmenar de Oreja', 'Ambite', 'Pinto', 'Daganzo de Arriba', 'Valdemanco', 'Villa del Prado', 'Anchuelo', 'Collado Villalba', 'Cobeña', 'Fuente El Saz de Jarama', 'Galapagar', 'Orusco de Tajuña', 'El Molar (Madrid)', 'Guadalix de la Sierra', 'Serranillos del Valle', 'Lozoya', 'Quijorna', 'Aranjuez', 'Robledo de Chavela', 'Collado Mediano', 'Villanueva de la Cañada', 'Camarma de Esteruelas', 'Villaconejos', 'San Lorenzo de El Escorial', 'Manzanares El Real', 'San Sebastián de los Reyes', 'Villarejo de Salvanés', 'Algete', 'Alcobendas', 'Tielmes', 'El Atazar', 'Torrejón de Velasco', 'La Cabrera', 'Navas del Rey', 'Colmenar Viejo', 'Torres de la Alameda', 'Arganda del Rey', 'Navalcarnero', 'Becerril de la Sierra', 'Ajalvir', 'Chapinería', 'Estremera', 'Arroyomolinos (Madrid)', 'Navarredonda', 'Cubas de la Sagra', 'Zarzalejo', 'Pedrezuela', 
# ...

# %%
populations_list = ds['level5'].unique()
print(populations_list)
# Out:
# ['Arganda del Rey' 'Fuenlabrada' 'Boadilla del Monte'
#  'Las Rozas de Madrid' ' Madrid Capital' 'Villaviciosa de Odón' 'Pinto'
#  'Valdemoro' 'Navalcarnero' 'Pozuelo de Alarcón' 'Torrejón de Ardoz'
#  'Navalagamella' 'San Sebastián de los Reyes' 'Rivas-vaciamadrid'
#  'Alpedrete' 'Móstoles' 'San Fernando de Henares' 'Coslada'
#  'Becerril de la Sierra' 'Alcalá de Henares' 'Chinchón' 'Parla' 'Alcorcón'
#  'El Escorial' 'Leganés' 'Pedrezuela' 'Majadahonda'
#  'Villanueva de la Cañada' 'Villanueva del Pardillo' 'Torrelodones'
#  'Moralzarzal' 'Mejorada del Campo' 'Aranjuez' 'Corpa' 'Getafe'
#  'Velilla de San Antonio' 'Sevilla la Nueva' 'San Martín de la Vega'
#  'Villalbilla' 'Collado Villalba' 'Alcobendas' 'El Molar (Madrid)'
#  'Moraleja de Enmedio' 'Algete' 'Campo Real' 'Torrejón de la Calzada'
#  'Colmenar Viejo' 'Valdemorillo' 'Fuente El Saz de Jarama' 'Tres Cantos'
#  'Arroyomolinos (Madrid)' 'Griñón' 'Paracuellos de Jarama' 'Guadarrama'
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0              0
# id_realEstates          0
# isNew                   0
# realEstate_name        10
# phone_realEstate      794
# url_inmueble            0
# rooms                 353
# bathrooms             345
# surface              1250
# price                   0
# date                    0
# description           142
# address                 0
# country                 0
# level1                  0
# level2                  0
# level3                  0
# level4               6643
# level5                  0
# level6              14627
# level7               2277
# level8               8579
# upperLevel              0
# countryId               0
# level1Id                0
# level2Id                0
# level3Id                0
# level4Id                0
# level5Id                0
# level6Id                0
# level7Id                0
# level8Id                0
# accuracy                0
# latitude                0
# longitude               0
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
cols_null = ['zipCode', 'customZone', 'level4', 'level6', 'level7', 'level8']

ds_clean = ds.drop(cols_null, axis=1)

print(ds_clean.shape)

ds_clean = ds_clean.dropna()

print(ds_clean.shape)

ds_clean = ds_clean[ds_clean['price']!=0]

print(ds_clean.shape)
# Out:
# (15335, 31)
# (12831, 31)
# (12779, 31)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
ds_clean['population'] = ds_clean['level5']

ds_arroyomolinos = ds_clean[ds_clean['population']== 'Arroyomolinos (Madrid)']

arroyomolinos_price_mean = round(ds_arroyomolinos['price'].mean(), 2)

print(f'The mean price of the house in Arroyomolinos (Madrid) is: {arroyomolinos_price_mean}€')
# Out:
# The mean price of the house in Arroyomolinos (Madrid) is: 298780.22€

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 5))

plt.hist(ds_arroyomolinos['price'], bins = 30, alpha = 0.7)

plt.title("Histogram")
plt.xlabel("Price")
plt.ylabel("Amount")
plt.show()

# %% [markdown]
# Most of the houses have a price between 200.000€ and 300.000€, and there are a few houses with a price under 100.000€. As well, there is a large amount of houses with a representative amount with a price between 300.000€ and 400.000€. We also can observ there is a few overpriced houses over the 400.000€ price range.

# %% [markdown]
# #### Exercise 09. Are the averages of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
ds_valdemorillo = ds_clean[ds_clean['population']== 'Valdemorillo']
ds_galapagar = ds_clean[ds_clean['population']== 'Galapagar']

valdemorillo_price_mean = round(ds_valdemorillo['price'].mean(), 2)
galapagar_price_mean = round(ds_galapagar['price'].mean(), 2)

print(f'The mean price of the house in Valdemorillo is: {valdemorillo_price_mean}€')   
print(f'The mean price of the house in Galapagar is: {galapagar_price_mean}€')
# Out:
# The mean price of the house in Valdemorillo is: 384269.57€
# The mean price of the house in Galapagar is: 381106.7€

# %% [markdown]
# #### Exercise 10. Are the averages of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
ds_clean['pps'] = ds_clean['price']/ds_clean['surface']

# Actualizamos con estos subsets de 'Valdemorillo' y 'Galapagar' para que incluyan las modificaciones del dataframe principal ('ds_clean)

ds_valdemorillo = ds_clean[ds_clean['population']== 'Valdemorillo']
ds_galapagar = ds_clean[ds_clean['population']== 'Galapagar']

print(f"Valdemorillo pps average: {round(ds_valdemorillo['pps'].mean(),2)} with {len(ds_valdemorillo['price'])} different houses")
print(f"Galapagar pps average: {round(ds_galapagar['pps'].mean(),2)} with {len(ds_galapagar['price'])} different houses")
# Out:
# Valdemorillo pps average: 1321.77 with 46 different houses
# Galapagar pps average: 1566.52 with 67 different houses

# %% [markdown]
# With this information we can say that the houses in Valdemorillo are cheaper or bigger than houses in Galapagar.
# Moreover we can say too that the houses of Galapagar are smaller or more expensive than the houses of Valdemorillo.

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
# Create plot
plt.figure(figsize = (10, 5))

# Add data
plt.scatter(ds_valdemorillo['price'], ds_valdemorillo['surface'], label = "Valdemorillo")
plt.scatter(ds_galapagar['price'], ds_galapagar['surface'], label = "Galapagar")

plt.title("Scatter plot")
plt.xlabel("Price")
plt.ylabel("Surface (m2)")
plt.legend()
plt.show()

# %% [markdown]
# We can observe that removing the outliers of the graphic we confirm our hypothesis from before: houses in Valdemorillo are bigger and cheaper than houses of Galapagar, which are smaller and more expensive.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
realstates_list = ds_clean['realEstate_name'].to_list()

realstates_set = set(realstates_list)

realstates_list = list(realstates_set)

print(f" The number of the realstates in the dataset is {len(realstates_list)}")
# Out:
#  The number of the realstates in the dataset is 1439

# %%
unique_realstates = ds_clean['realEstate_name'].unique()

quantity_realstates = len(unique_realstates)

print(f" The number of the realstates in the dataset is {quantity_realstates}")
# Out:
#  The number of the realstates in the dataset is 1439

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
population = ds_clean["level5"].value_counts()

population_index = population.idxmax() 
population_maxcount = population.max()

print(f"The population with more houses is {population_index} with {population_maxcount} houses")
# Out:
# The population with more houses is  Madrid Capital with 5649 houses

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
populations_list = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

ds_southbelt = ds_clean[ds_clean["population"].isin(populations_list)]

ds_southbelt
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 3               4       152776331  False
# 94             95       153995577  False
# 109           110       153586414  False
# 161           162       153440116  False
# 169           170       153920011  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# 161                                    prolucisa       916350416.0
# 169                                 grupo tizona       911226046.0
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
# populations_list = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

def get_mean_southbelt(col):
    values = []
    
    for n in populations_list:
        ds_aux = ds_southbelt[ds_southbelt['population'] == n]
        values.append(round(ds_aux[col].mean(), 3))
    return values

plt.figure(figsize = (10, 5))

plt.bar(populations_list, get_mean_southbelt('price'))

plt.title("South Belt of Madrid")
plt.xlabel("Population")
plt.ylabel("Mean Price")
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
def get_variance_southbelt(df : pd.DataFrame, column_check : pd.Series, mean_value : float):
    # variance = (Sum((data_list - mean_value) ** 2))/n_elements
    variance = ((df[column_check] - mean_value) ** 2).sum() / len(df)
    return round(variance, 3)


cols_to_get = ['price', 'rooms', 'surface', 'bathrooms'] # columnas donde queremos saber la media y/o varianza


aux = 0 # Para saber en qué columna estamos
for col in cols_to_get:
    mean_v = get_mean_southbelt(col) # conseguimos la media y la guardamos
    variance_v = get_variance_southbelt(ds, col, mean_v[aux]) # conseguimos la varianza, miramos la media en mean_v[aux] donde aux es la posición del vector que coincide con cols_to_get siempre
    print(f"The mean {col} is {mean_v[aux]} and the variance is {variance_v}") # imprimimos por pantalla
    aux+=1 # We move to next cols_to_get index
# Out:
# The mean price is 181048.456 and the variance is 437373159720.918
# The mean rooms is 2.908 and the variance is 1.998
# The mean surface is 122.187 and the variance is 4380889.722
# The mean bathrooms is 1.643 and the variance is 1.883

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
def get_max(df, col):
    aux = []
    for n in populations_list:
        df_aux = df[df['population']== n]
        aux.append(df_aux[col].idxmax())
    return aux  

max_aux_index = get_max(ds_southbelt, 'price')

ds_southbelt.loc[max_aux_index]
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 11561       11562       153660921  False
# 10412       10413       152251506  False
# 2881         2882       151105544  False
# 5585         5586       153275915  False
#
#                                realEstate_name  phone_realEstate  \
# 11561                              unna madrid       912780846.0
# 10412  bafre gestion y servicios inmobiliarios       910752245.0
# 2881                   unna grupo inmobiliario       912665694.0
# 5585                 100 home red inmobiliaria       912669623.0
#
#                                             url_inmueble  rooms  bathrooms  \
# 11561  https://www.fotocasa.es/es/comprar/vivienda/va...    4.0        3.0
# 10412  https://www.fotocasa.es/es/comprar/vivienda/co...    6.0        5.0
# 2881   https://www.fotocasa.es/es/comprar/vivienda/ma...    6.0        4.0
# 5585   https://www.fotocasa.es/es/comprar/vivienda/ca...    6.0        6.0
#
# ...

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
def normalized(df):

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
ds_clean['pps'] = ds_clean['price']/ds_clean['surface']

pps_Getafe= ds_southbelt[ds_southbelt['pps']== 'Getafe']
pps_Alcorcón = ds_southbelt[ds_southbelt['pps']== 'Alcorcón']

print(pps_Getafe)
print(pps_Alcorcón)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id_realEstates, isNew, realEstate_name, phone_realEstate, url_inmueble, rooms, bathrooms, surface, price, date, description, address, country, level1, level2, level3, level5, upperLevel, countryId, level1Id, level2Id, level3Id, level4Id, level5Id, level6Id, level7Id, level8Id, accuracy, latitude, longitude, population, pps]
# Index: []
#
# [0 rows x 33 columns]
# Empty DataFrame
# Columns: [Unnamed: 0, id_realEstates, isNew, realEstate_name, phone_realEstate, url_inmueble, rooms, bathrooms, surface, price, date, description, address, country, level1, level2, level3, level5, upperLevel, countryId, level1Id, level2Id, level3Id, level4Id, level5Id, level6Id, level7Id, level8Id, accuracy, latitude, longitude, population, pps]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
# TODO

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 6
#       1 from ipyleaflet import Map, basemaps
#       3 # Map centred on (60 degrees latitude et -2.2 degrees longitude)
#       4 # Latitude, longitude
#       5 map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
# ----> 6     basemap=basemaps.Stamen.Terrain)
#       7 map
#
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:46, in Bunch.__getattr__(self, key)
#      44     return self.__getitem__(key)
# ...

# %%
## HERE: plot the coordinates of the estates

## PUT HERE YOUR CODE:
